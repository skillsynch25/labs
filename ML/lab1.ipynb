# %% [markdown]
# # 🤖 Neural Network Lab: Building a Simple Classifier
#
# In this lab, you'll build a simple neural network classifier using TensorFlow and Keras. We'll walk through the entire process step-by-step, including data loading, preprocessing, model building, training, and evaluation.
#
# We'll use the classic **MNIST dataset** of handwritten digits (0–9).
